# %% [markdown]
# # CS 559: Final Project - Generalization
# Zheng Ke Xu, Yashvi, Annanya Chaturvedi

# %% [markdown]
# ## 1. Generalization - Section 4
# Data prediction using our trained composite model.

# %%
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

df_train = pd.read_csv('./train_data.csv').drop(columns=["Index", " Net Income Flag"])
df_test = pd.read_csv('./test_data.csv').drop(columns=["Index", " Net Income Flag"])

preprocess_data = joblib.load('preprocess_data.joblib')
processed_features, test_features, corr_matrix = preprocess_data(df_train=df_train, df_test=df_test)

print(test_features)
# Out:
#       ROA(C) before interest and depreciation before interest  \
# 0                                              0.414323
# 1                                              0.497441
# 2                                              0.501584
# 3                                              0.574465
# 4                                              0.393360
# ...                                                 ...
# 1007                                           0.495783
# 1008                                           0.556038
# 1009                                           0.580705
# 1010                                           0.459465
# 1011                                           0.502608
#
#       ROA(A) before interest and % after tax  \
# 0                                   0.481029
# 1                                   0.560892
# 2                                   0.548899
# 3                                   0.637375
# 4                                   0.456444
# ...
